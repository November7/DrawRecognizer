# %% [markdown]
# ## Konwersja modelu Tensorflow od Teachable Machinedo formatu ONNX
#
# Wyeksportuj model z Teachable Machine (Tensorflow savedmodel), umieść rozpakowany folder w katalogu 'tensorflow' i uruchom poniższy kod.
#
# Przykładowa struktura katalogów (przy założeniu, że model nazywa się 'cyfry.tm' wyeksportowany z Teachable Machine):
#
# ```
# tensorflow-models/
#     cyfry.tm/
#         assets/
#         saved_model.pb
#         variables/
#         labels.txt
# ```

# %%
import shutil

teachable_machine_model_name = "./tensorflow-models/cyfry.tm"

# !python -m tf2onnx.convert --saved-model {teachable_machine_model_name} --output {teachable_machine_model_name}.onnx
# Out:
# 2026-06-18 13:24:35.213202: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-06-18 13:24:36.103014: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING:tensorflow:From c:\Users\MarcinKowalski\.conda\envs\tf\Lib\site-packages\tf2onnx\tf_loader.py:190: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# 2026-06-18 13:24:39,039 - WARNING - From c:\Users\MarcinKowalski\.conda\envs\tf\Lib\site-packages\tf2onnx\tf_loader.py:190: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# 2026-06-18 13:24:39.040908: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-06-18 13:24:39,040 - WARNING - '--tag' not specified for saved_model. Using --tag serve
# 2026-06-18 13:24:44,705 - INFO - Fingerprint not found. Saved model loading will continue.
# 2026-06-18 13:24:44,705 - INFO - path_and_singleprint metric could not be logged. Saved model loading will continue.
# 2026-06-18 13:24:44,705 - INFO - Signatures found in model: [serving_default].
# 2026-06-18 13:24:44,705 - WARNING - '--signature_def' not specified, using first signature: serving_default
# 2026-06-18 13:24:44,706 - INFO - Output names: ['sequential_3']
# 2026-06-18 13:24:44.714678: I tensorflow/core/grappler/devices.cc:75] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# 2026-06-18 13:24:44.715177: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# WARNING:tensorflow:From c:\Users\MarcinKowalski\.conda\envs\tf\Lib\site-packages\tf2onnx\tf_loader.py:834: The name tf.train.export_meta_graph is deprecated. Please use tf.compat.v1.train.export_meta_graph instead.
#
# 2026-06-18 13:24:45,478 - WARNING - From c:\Users\MarcinKowalski\.conda\envs\tf\Lib\site-packages\tf2onnx\tf_loader.py:834: The name tf.train.export_meta_graph is deprecated. Please use tf.compat.v1.train.export_meta_graph instead.
#
# 2026-06-18 13:24:45.490011: I tensorflow/core/grappler/devices.cc:75] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# 2026-06-18 13:24:45.490456: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2026-06-18 13:24:45,631 - INFO - Using tensorflow=2.16.1, onnx=1.22.0, tf2onnx=1.17.0/None
# 2026-06-18 13:24:45,631 - INFO - Using opset <onnx, 15>
# 2026-06-18 13:24:45,733 - INFO - Computed 0 values for constant folding
# 2026-06-18 13:24:45,947 - INFO - Optimizing ONNX model
# 2026-06-18 13:24:47,307 - INFO - After optimization: BatchNormalization -52 (52->0), Const -248 (359->111), GlobalAveragePool +1 (0->1), Identity -2 (2->0), ReduceMean -1 (1->0), Reshape -17 (17->0), Squeeze +1 (0->1), Transpose -224 (225->1)
# 2026-06-18 13:24:47,319 - INFO -
# 2026-06-18 13:24:47,319 - INFO - Successfully converted TensorFlow model ./tensorflow-models/cyfry.tm to ONNX
# 2026-06-18 13:24:47,319 - INFO - Model inputs: ['sequential_1_input']
# 2026-06-18 13:24:47,319 - INFO - Model outputs: ['sequential_3']
# 2026-06-18 13:24:47,319 - INFO - ONNX model is saved at ./tensorflow-models/cyfry.tm.onnx

# %% [markdown]
# ## Dodanie etykiet klas do pliku ONNX (opcjonalne)

# %%
import onnx
import shutil
import os

labels = []

with open(teachable_machine_model_name + "/labels.txt", "r") as f:
    for line in f:
        index, name = line.strip().split()
        labels.append(name)

model = onnx.load(teachable_machine_model_name + ".onnx")

meta = model.metadata_props.add()
meta.key = "labels"
meta.value = ",".join(labels)

onnx.save(model, teachable_machine_model_name + ".onnx")

shutil.rmtree(teachable_machine_model_name)
